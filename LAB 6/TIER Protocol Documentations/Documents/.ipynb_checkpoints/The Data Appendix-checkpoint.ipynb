# %% [markdown]
# # Analiza i Bazy Danych
# ## Karol Musiał, grupa 3a
# ### Laboratorium 6
# ## "Exploratory Data Analysis"

# %%
# Importowanie
from matplotlib import pyplot as plt
import pandas as pd

# Wczytywanie danych
data = pd.read_csv('../Analysis Data/new_data.csv')
DF = pd.DataFrame(data)

# %%
# Histogramy
DF['Days'].plot(kind='hist',title='Days',density=True,bins=15)
plt.show()
DF['Age'].plot(kind='hist',title='Age',density=True,bins=40)
plt.show()
DF['Score'].plot(kind='hist',title='Score',density=True,bins=11)
plt.show()
