# %% [markdown]
# # Analiza i Bazy Danych
# ## Karol Musiał, grupa 3a
# ### Laboratorium 8
# ## "Podstawy Analizy Języka Naturalnego"

# %%
# Importowanie modułów
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Łączenie z bazą danych
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_classifier_abd"
db = create_engine(db_string)

# %%
# Popularnosc kategorii
select_string="SELECT setseed(0.5); SELECT genres.name, count(movies) FROM movies JOIN genres_movies "\
              "ON movies.movie_id = genres_movies.movie_id JOIN genres ON genres_movies.genre_id = genres.genre_id "\
              "WHERE random() > 0.9 GROUP BY genres.name ORDER BY count(movies) DESC"  
df=pd.read_sql(select_string,con=db)
df.head(10)
# Out:
#               name  count
# 0         Thriller    536
# 1            Drama    532
# 2       Short Film    329
# 3    Crime Fiction    280
# 4  Romantic comedy    187
# 5     Romance Film    183
# 6      Comedy film    115
# 7           Horror    112
# 8           Comedy    107
# 9          Musical    106

# %% [markdown]
# #### <b> Wybrano kategorie numerze ID (11%10) = 1 - Drama <b>

# %%
# Baza danych filmów
select_string="SELECT setseed(0.5); SELECT movies.movie_name, movies.plot, genres.name FROM movies JOIN genres_movies "\
              "ON movies.movie_id = genres_movies.movie_id JOIN genres ON genres_movies.genre_id = genres.genre_id "\
              "WHERE random() > 0.9"  

df=pd.read_sql(select_string,con=db)
df
# Out:
#                      movie_name  \
# 0           Flåklypa Grand Prix
# 1           Saving Private Ryan
# 2                      The Rock
# 3      The Silence of the Lambs
# 4                The Terminator
# ...                         ...
# 4246                     Tomchi
# 4247            Every 9 Seconds
# 4248           Shanghai Calling
# 4249  Shark Attack 3: Megalodon
# 4250                Mr. Bechara
#
#                                                    plot           name
# 0       In the town of Flåklypa , the inventor Reodo...    Stop motion
# 1     On the morning of June 6, 1944, the beginning ...  Ensemble Film
# 2     A group of rogue Force Recon Marines led by di...       Thriller
# 3     Clarice Starling  is pulled from her training ...       Thriller
# 4      In a post-apocalyptic 2029, artificially inte...       Thriller
# ...                                                 ...            ...
# 4246  Tomchi is a story of six notorious children wh...          Drama
# ...

# %%
# Kolumna przypisujaca 1 lub 0 w zaleznosci od gatunku
df['drama'] = 0
df.loc[df.name == 'Drama', 'drama'] = 1
df
# Out:
#                      movie_name  \
# 0           Flåklypa Grand Prix
# 1           Saving Private Ryan
# 2                      The Rock
# 3      The Silence of the Lambs
# 4                The Terminator
# ...                         ...
# 4246                     Tomchi
# 4247            Every 9 Seconds
# 4248           Shanghai Calling
# 4249  Shark Attack 3: Megalodon
# 4250                Mr. Bechara
#
#                                                    plot           name  drama
# 0       In the town of Flåklypa , the inventor Reodo...    Stop motion      0
# 1     On the morning of June 6, 1944, the beginning ...  Ensemble Film      0
# 2     A group of rogue Force Recon Marines led by di...       Thriller      0
# 3     Clarice Starling  is pulled from her training ...       Thriller      0
# 4      In a post-apocalyptic 2029, artificially inte...       Thriller      0
# ...                                                 ...            ...    ...
# ...

# %%
# Tworzenie bag of words
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(lowercase=True, strip_accents='ascii', stop_words='english', max_features=20)

# Przekształcanie opisów do zadanej postaci
X = vectorizer.fit_transform(df['plot'])
y = df['drama']

# Dzielenie na zbiory uczące i testujące
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Tworzenie modelu
LRM = LogisticRegression(max_iter = 1000)
LRM.fit(X_train, y_train)

# Wypisywanie wskaznikow
print("\nCoef = {a}".format(a=LRM.coef_))
print("Intercept = {a}\n".format(a=LRM.intercept_))

# Predykcja czesci testowej
y_pred = LRM.predict(X_test)
print("Roznica miedzy predykcja a rzeczywistym wynikiem : \n{a}\n".format(a=(y_pred - y_test)))

# Walidacja danych
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
cr = classification_report(y_test, y_pred)
print('\nŚredni błąd bezwzględny = {a}'.format(a=mae))
print('Błąd średniokwadratowy = {a}'.format(a=mse))
print('Pierwiastek błędu średniokwadratowego = {a}\n'.format(a=rmse))
print('Raport:\n{a}\n\n'.format(a=cr))

# Confusion Matrix
c_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(c_matrix)
# Out:
# Coef = [[-0.09772008  0.09627946  0.11657768  0.08175692  0.09089609 -0.14369126
#   -0.08864824 -0.02303518  0.13351927 -0.2857347   0.11024176 -0.06141499
#   -0.11880887  0.13929556 -0.05970708 -0.09389602  0.10711926 -0.07873194
#    0.00414893 -0.22734768]]
# Intercept = [-1.86086063]
#
# Roznica miedzy predykcja a rzeczywistym wynikiem :
# 1024    0
# 2179    0
# 4104    0
# 3622   -1
# 4130   -1
#        ..
# 2905    0
# 3426    0
# 2457    0
# 836     0
# 3767    0
# Name: drama, Length: 1403, dtype: int64
#
#
# Średni błąd bezwzględny = 0.11831789023521026
# Błąd średniokwadratowy = 0.11831789023521026
# Pierwiastek błędu średniokwadratowego = 0.3439736766603082
#
# Raport:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      1239
#            1       0.00      0.00      0.00       164
#
#     accuracy                           0.88      1403
#    macro avg       0.44      0.50      0.47      1403
# ...

# %% [markdown]
# #### <b> Model poprawnie znalazł znaczną większość gatunków innych niż dramat. Na 1239, 1237 zostało poprawinie zakwaflifikowane jako inne, natomaist 2 zostały błędnie przypisane jako dramat. Na 164 dramaty, żaden nie został poprawnie przypisany, model wszystkie przypadki uznał za gatunek inny niż dramat. <b>

# %%
# Prawdopodobienstwa 
predict_probabilities = LRM.predict_proba(X)[:,1]
fpr, tpr, _ = roc_curve(y, predict_probabilities)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Krzywa ROC')
plt.show()

# Obliczenia z confusion matrix
false_pos = (c_matrix[0][1]/sum(c_matrix[0])) * 100
false_neg = (c_matrix[1][0]/sum(c_matrix[1])) * 100

print("Szansa otrzymania wyniku fałszywie pozytywnego to: {a:.2f}%".format(a=false_pos))
print("Szansa otrzymania wyniku fałszywie negatywnego to: {a:.2f}%".format(a=false_neg))
# Out:
# Szansa otrzymania wyniku fałszywie pozytywnego to: 0.16%
# Szansa otrzymania wyniku fałszywie negatywnego to: 100.00%
