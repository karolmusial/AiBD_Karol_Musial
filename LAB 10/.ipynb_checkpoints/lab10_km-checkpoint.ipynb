# %% [markdown]
# # Analiza i Bazy Danych
# ## Karol Musiał, grupa 3a
# ### Laboratorium 10
# ## "Modelowanie szeregów czasowych"

# %%
# Importowanie bibliotek
import pandas as pd
from pandas import DataFrame
import datetime 
from matplotlib import pyplot
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
from pmdarima import model_selection
import numpy as np
# %matplotlib inline

# %%
# Odczytanie danych
DF = pd.read_csv("analiza.csv", sep = ",", decimal = ",")
print(DF.head())
print("\n")
print(DF.describe())
print("\n")
print(DF.shape)
# Out:
#       Data  Rezerwacja
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
#
#
#        Rezerwacja
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000
#
#
# (144, 2)

# %%
# Wstępny wykres danych
DF['Data'] = pd.to_datetime(DF['Data'])
DF = DF.set_index('Data')
plt.plot(DF, linestyle='none', marker='o')
plt.ylabel('Numer rezerwacji')
plt.xlabel('Data')
plt.title('Wykres rozrzutu')
plt.show()

# %% [markdown]
# #### <b> Zaobserwowana na wykresie korelacja jest dodatnia, jej typ jest pomiędzy liniowym a wykładniczym. <b>

# %%
# Obliczanie ADF
DF_rezerwacja = pd.read_csv('analiza.csv', header=0, index_col=0)
result = adfuller(DF_rezerwacja.values)
print('ADF Statistic: %f' % result[1])
print('p-value: %f' % result[0])
# Out:
# ADF Statistic: 0.991880
# p-value: 0.815369

# %% [markdown]
# #### <b> Za alpha przyjęto wartość 5%, p-value jest większy, co oznacza, że nie możemy obalić hipotezy zerowej, a ciąg prawdopodobnie jest niestacjonarny. Ten sam wniosek można wysnuć na podstawie analizy wykresu - widać, że wartość średnia i wariancja zmieniają się w czasie  <b>

# %%
# Wykres funkcji autokorelacji ACF
plot_acf(DF_rezerwacja, zero=False, lags=10)
plt.show()

# %% [markdown]
# #### <b> Wykres pokazuje, że największe znaczenie w przewidywaniu przyszłych wyników mają próbki o mniejszym przesunięciu. <b>

# %%
# Wykres częsciowej funkcji autokorelacji PACF
plot_pacf(DF_rezerwacja, zero=False, lags=10, method='ywm')
plt.show()

# %% [markdown]
# #### <b> Największe powiązanie ma miejsce w przypadku 1 próbki, wartość bezwzględna korelacji jest bliska 1, dodatkowo korelacja ta jest dodatnia, czyli duże wartości bieżące odpowiadają dużym wartościom przesunięcia. <b>

# %%
# Podział szeregu oraz obliczanie kryterium AIC
X = DF_rezerwacja.values
train = X[0:106]
test = X[106:]
predictions = [train, test]
model = ARIMA(DF_rezerwacja, order=(3,0,1), freq="MS")
results = model.fit()
print(results.summary())
# Out:
# /home/user/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Rezerwacja   No. Observations:                  144
# Model:                 ARIMA(3, 0, 1)   Log Likelihood                -698.144
# Date:                Fri, 10 Dec 2021   AIC                           1408.288
# Time:                        13:21:28   BIC                           1426.107
# Sample:                    01-01-1949   HQIC                          1415.528
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        280.3011     58.857      4.762      0.000     164.944     395.658
# ar.L1          0.5019      0.133      3.776      0.000       0.241       0.762
# ar.L2          0.5505      0.157      3.506      0.000       0.243       0.858
# ar.L3         -0.1331      0.093     -1.435      0.151      -0.315       0.049
# ma.L1          0.8966      0.086     10.440      0.000       0.728       1.065
# sigma2       929.8218    106.908      8.697      0.000     720.286    1139.357
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.80
# Prob(Q):                              0.95   Prob(JB):                         0.41
# Heteroskedasticity (H):               6.28   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### <b> Kryterium AIC dla tego modelu - ARIMA(3, 0, 1) ma wartość 1408. <b>

# %%
# Dobranie najlepszego modelu dla prognozy AUTO-ARIMA
AUTO_ARIMA=pm.auto_arima(DF_rezerwacja, exogenous=None, seasonal=False, m=1, d=1, D=1,
                     max_p=4, max_q=3, trace=True, error_action='ignore', suppress_warning=True)
print(AUTO_ARIMA.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1415.278, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1403.473, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1398.827, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1413.909, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1396.121, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1398.386, Time=0.12 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1397.975, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1394.683, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1397.258, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1401.852, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1378.338, Time=0.15 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1396.588, Time=0.07 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1379.614, Time=0.22 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1385.498, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=1395.021, Time=0.05 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1377.086, Time=0.32 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=1373.560, Time=0.28 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=1384.053, Time=0.28 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=1365.825, Time=0.44 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=0.48 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.54 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0]
# Total fit time: 5.377 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:               SARIMAX(4, 1, 3)   Log Likelihood                -674.913
# Date:                Fri, 10 Dec 2021   AIC                           1365.825
# Time:                        13:21:34   BIC                           1389.528
# Sample:                             0   HQIC                          1375.457
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5582      0.117     -4.782      0.000      -0.787      -0.329
# ar.L2          0.4935      0.113      4.375      0.000       0.272       0.715
# ar.L3          0.1238      0.128      0.970      0.332      -0.126       0.374
# ar.L4         -0.5213      0.085     -6.136      0.000      -0.688      -0.355
# ma.L1          0.9069      0.094      9.657      0.000       0.723       1.091
# ma.L2         -0.5590      0.145     -3.866      0.000      -0.842      -0.276
# ma.L3         -0.7385      0.109     -6.778      0.000      -0.952      -0.525
# sigma2       724.1724     85.616      8.458      0.000     556.369     891.976
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):                14.59
# Prob(Q):                              0.54   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.66   Skew:                             0.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### <b> Automatycznie wybrany model - ARIMA(4, 1, 3), ma najniższą wartość kryterium AIC ze wszystkich testowanych - 1365. <b>

# %%
# Wykres prognozy
AUTO_ARIMA.fit(train)
pred = AUTO_ARIMA.predict(38)

fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot()
ax1.plot(test, linestyle='none', marker='o', label='real')
ax1.plot(pred, linestyle='none', marker='o', label='predicted')
plt.ylabel('Numer rezerwacji')
plt.title('Wykres prognozy')
plt.legend()
plt.show()

# %% [markdown]
# #### <b> Prognoza sprawdziła się całkiem dobrze, większość próbek pokrywa się z rzeczywistymi. W niektórych przypadkach przewidywania mają mniejsze wartości, jednak trend zmian kolejnych próbek jest zachowany. <b>
